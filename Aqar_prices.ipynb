# %%
import pandas as pd

df = pd.read_csv("https://github.com/AFAskar/aqar-scraper/raw/refs/heads/main/aqar_fm_listings.csv")

# %%
df.head()
# Out:
#         id                                              title  \
# 0  6502998  دور للبيع في شارع شهيد الدين ثم الوطن فهد إبرا...
# 1  6428644  فيلا للبيع في شارع أحمد بن حيان, حي الملقا, مد...
# 2  6516181  دور للإيجار في شارع شداد بن أوس, حي العليا, مد...
# 3  6495984  شقة للبيع في شارع الغائر, حي المروج, مدينة أبه...
# 4  6513148  شقة للبيع في شارع السالمية, حي البحيرة, مدينة ...
#
#                                                  url       price  meter_price  \
# 0  https://sa.aqar.fm/دور-للبيع/الرياض/شمال-الريا...   1500000.0          NaN
# 1  https://sa.aqar.fm/فلل-للبيع/الرياض/شمال-الريا...  13500000.0          NaN
# 2  https://sa.aqar.fm/دور-للإيجار/الرياض/شمال-الر...    105000.0          NaN
# 3  https://sa.aqar.fm/شقق-للبيع/ابها/حي-درة-المنس...    635000.0          NaN
# 4  https://sa.aqar.fm/شقق-للبيع/ابها/حي-ابها-الجد...    510000.0          NaN
#
#    price_2_payments  price_4_payments  price_12_payments  rnpl_monthly_price  \
# ...

# %%
print(df.columns.tolist())
# Out:
# ['id', 'title', 'url', 'price', 'meter_price', 'price_2_payments', 'price_4_payments', 'price_12_payments', 'rnpl_monthly_price', 'area_sqm', 'deed_area', 'num_bedrooms', 'num_bathrooms', 'num_living_rooms', 'num_kitchens', 'num_rooms', 'floor_level', 'furnished', 'duplex', 'ac', 'lift', 'maid_room', 'driver_room', 'pool', 'basement', 'backyard', 'playground', 'car_entrance', 'stairs', 'water_availability', 'electrical_availability', 'drainage_availability', 'private_roof', 'two_entrances', 'special_entrance', 'apartment_in_villa', 'street_width', 'direction', 'city', 'district', 'address', 'latitude', 'longitude', 'category_id', 'category_ga_listing_type', 'category_ga_property_category', 'category_is_rent', 'category_name', 'category_en', 'category_plural', 'category_uri', 'category_path', 'category_keywords', 'category_description', 'category_index', 'sale_type', 'is_rental', 'is_sale', 'is_auction', 'is_daily_rental', 'create_time', 'published_at', 'last_update', 'verified', 'boo
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6260 entries, 0 to 6259
# Data columns (total 79 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             6260 non-null   int64
#  1   title                          6251 non-null   object
#  2   url                            6260 non-null   object
#  3   price                          6260 non-null   float64
#  4   meter_price                    431 non-null    float64
#  5   price_2_payments               617 non-null    float64
#  6   price_4_payments               596 non-null    float64
#  7   price_12_payments              598 non-null    float64
#  8   rnpl_monthly_price             950 non-null    float64
#  9   area_sqm                       6260 non-null   int64
#  10  deed_area                      6249 non-null   float64
#  11  num_bedrooms                   5487 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# title                9
# url                  0
# price                0
# meter_price       5829
#                   ...
# company_name       318
# user_paid_tier     192
# description         34
# images               0
# videos               0
# Length: 79, dtype: int64

# %%
y = df[['price']]

X = df[['area_sqm','num_bedrooms', 'num_rooms', 'num_bathrooms', 'city', 'district']].copy()

# %%
X.isnull().sum()
# Out:
# area_sqm            0
# num_bedrooms      773
# num_rooms         490
# num_bathrooms    2737
# city                0
# district            0
# dtype: int64

# %%
# 1. Fill Numerical NaNs with Median
numerical_cols = ['area_sqm', 'num_bedrooms', 'num_rooms', 'num_bathrooms']
for col in numerical_cols:
    X[col] = X[col].fillna(X[col].median())

# 2. Fill Categorical NaNs with a placeholder
categorical_cols = ['city', 'district']
for col in categorical_cols:
    X[col] = X[col].fillna('Unknown')

# 3. One-Hot Encode the text columns
X_final = pd.get_dummies(X, columns=['city', 'district'])

# Check if any NaNs remain
print(X_final.isnull().sum().sum())
# Out:
# 0

# %%
X.isnull().sum()
# Out:
# area_sqm         0
# num_bedrooms     0
# num_rooms        0
# num_bathrooms    0
# city             0
# district         0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

# Calculate MSE first
mse = mean_squared_error(y_test, y_pred)

# Take the square root to get RMSE
rmse = np.sqrt(mse)

print(f"On average, our model is off by: {rmse:,.2f} SAR")
# Out:
# On average, our model is off by: 6,397,620.72 SAR

# %%
# Calculate the median for bathrooms
median_bathrooms = X['num_bathrooms'].median()
print(f"The median number of bathrooms is: {median_bathrooms}")
# Out:
# The median number of bathrooms is: 3.0

# %%
df.shape
# Out:
# (6260, 79)

# %%
# Filtering to keep only sales
df_sale = df[df['is_sale'] == True]
df_sale.shape
# Out:
# (4903, 79)

# %%
y = df_sale[['price']]

X = df_sale[['area_sqm','num_bedrooms', 'num_rooms', 'num_bathrooms', 'city', 'district']].copy()

# %%
X.isnull().sum()
# Out:
# area_sqm            0
# num_bedrooms      657
# num_rooms         410
# num_bathrooms    2334
# city                0
# district            0
# dtype: int64

# %%
# 1. Fill Numerical NaNs with Median for the sales data
numerical_cols = ['area_sqm', 'num_bedrooms', 'num_rooms', 'num_bathrooms']
for col in numerical_cols:
    X[col] = X[col].fillna(X[col].median())

# 2. Fill Categorical NaNs
categorical_cols = ['city', 'district']
for col in categorical_cols:
    X[col] = X[col].fillna('Unknown')

# 3. Create the final version with One-Hot Encoding
X_final = pd.get_dummies(X, columns=['city', 'district'])

# Verify the result
print(X_final.isnull().sum().sum())
# Out:
# 0

# %%
X.isnull().sum()
# Out:
# area_sqm         0
# num_bedrooms     0
# num_rooms        0
# num_bathrooms    0
# city             0
# district         0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# Calculate MSE
mse_new = mean_squared_error(y_test, y_pred)

# Calculate RMSE
rmse_new = np.sqrt(mse_new)

print(f"New RMSE: {rmse_new:,.2f} SAR")
# Out:
# New RMSE: 2,888,704.62 SAR

# %% [markdown]
# ### Trying a different model

# %%
from sklearn.ensemble import RandomForestRegressor



rf_model = RandomForestRegressor()



rf_model.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestRegressor()

# %%
y_pred_rf = rf_model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# Calculate RMSE for the Random Forest
rmse_rf = np.sqrt(mean_squared_error(y_test, y_pred_rf))

print(f"Random Forest RMSE: {rmse_rf:,.2f} SAR")
# Out:
# Random Forest RMSE: 2,361,954.35 SAR

# %%
# Create a comparison table for the first 5 test samples
comparison_df = y_test.head(5).copy()
comparison_df['Predicted_Price'] = y_pred_rf[:5]
comparison_df['Difference'] = comparison_df['price'] - comparison_df['Predicted_Price']

print(comparison_df)
# Out:
#           price  Predicted_Price     Difference
# 5963   950000.0     8.117297e+05  138270.320937
# 4528  1380000.0     1.174300e+06  205700.000000
# 1237   850000.0     1.084388e+06 -234388.400000
# 3681   420000.0     5.327600e+05 -112760.000000
# 4026   480000.0     5.065453e+05  -26545.329365

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred_rf, alpha=0.5, color='royalblue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Actual Price (SAR)')
plt.ylabel('Predicted Price (SAR)')
plt.title('Actual vs Predicted House Prices (Random Forest)')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameters we want to change and test
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20]
}

# %%
# Initialize the search
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, 
                           scoring='neg_mean_squared_error', cv=3)

# Start the search
grid_search.fit(X_train, y_train.values.ravel())
# Out:
# GridSearchCV(cv=3, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 10, 20],
#                          'n_estimators': [50, 100, 200]},
#              scoring='neg_mean_squared_error')

# %%
# Use the best model found by GridSearchCV
best_rf = grid_search.best_estimator_

# Make predictions on the test set
y_pred_final = best_rf.predict(X_test)

# Calculate the final RMSE
final_rmse = np.sqrt(mean_squared_error(y_test, y_pred_final))
print(f"Optimized Random Forest RMSE: {final_rmse:,.2f} SAR")
# Out:
# Optimized Random Forest RMSE: 2,410,375.60 SAR

# %% [markdown]
# ### it seems the model got slightly worse results because i limited it too much

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# 1. Linear Regression Metrics
mae_lr = mean_absolute_error(y_test, y_pred)
r2_lr = r2_score(y_test, y_pred)

# 2. Initial Random Forest Metrics
mae_rf = mean_absolute_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

# 3. Optimized Random Forest Metrics
mae_rf_opt = mean_absolute_error(y_test, y_pred_final)
r2_rf_opt = r2_score(y_test, y_pred_final)

# Display Comparison Table
print(f"{'Model':<25} | {'MAE (SAR)':<15} | {'R2 Score':<10}")
print("-" * 55)
print(f"{'Linear Regression':<25} | {mae_lr:>15,.2f} | {r2_lr:>10.4f}")
print(f"{'Initial Random Forest':<25} | {mae_rf:>15,.2f} | {r2_rf:>10.4f}")
print(f"{'Optimized Random Forest':<25} | {mae_rf_opt:>15,.2f} | {r2_rf_opt:>10.4f}")
# Out:
# Model                     | MAE (SAR)       | R2 Score
# -------------------------------------------------------
# Linear Regression         |      729,826.95 |     0.0354
# Initial Random Forest     |      385,662.03 |     0.3551
# Optimized Random Forest   |      479,535.72 |     0.3284

# %%
import joblib

joblib.dump(rf_model, 'Aqar-prices_model.pkl')
# Out:
# ['Aqar-prices_model.pkl']
